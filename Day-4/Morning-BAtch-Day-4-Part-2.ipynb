# %%
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('titles.csv')
titles.head()
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
titles.groupby('title').size().sort_values()
# Out:
# title
# #211                                1
# Priklyuchenya Alenushki i Eremi     1
# Prikosnovenie vetra                 1
# Prikosnoveniye                      1
# Prikovannyy                         1
#                                    ..
# Temptation                         11
# The Outsider                       12
# Macbeth                            16
# Carmen                             17
# Hamlet                             20
# Length: 207630, dtype: int64

# %%
titles.title.value_counts().head(1)
# Out:
# title
# Hamlet    20
# Name: count, dtype: int64

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
t=titles
t = t[(t.year >= 1930) & (t.year <= 1939)]
# t.shape
t.year.value_counts().head(3)
# Out:
# year
# 1937    1217
# 1938    1161
# 1936    1153
# Name: count, dtype: int64

# %%
t = titles
t[t.year // 10 == 193].year.value_counts().head(3)
# Out:
# year
# 1937    1217
# 1938    1161
# 1936    1153
# Name: count, dtype: int64

# %%
t.year + 1000
# Out:
# 0         2953
# 1         2989
# 2         3006
# 3         2936
# 4         2933
#           ...
# 226008    2919
# 226009    3002
# 226010    2924
# 226011    2961
# 226012    2984
# Name: year, Length: 226013, dtype: int64

# %% [markdown]
# ### Plot the number of films that have been released each decade over the history of cinema.

# %%
1959 // 10 * 10
# Out:
# 1950

# %%
t = titles
t['decade'] = t.year // 10 * 10

t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %%
t.decade.value_counts()
# Out:
# decade
# 2010    65830
# 2000    35730
# 1990    21547
# 1980    19532
# 1970    18476
# 1960    17419
# 1950    12664
# 1930    10245
# 1920     8954
# 1940     8561
# 1910     6752
# 2020      260
# 1900       39
# 1890        3
# 2110        1
# Name: count, dtype: int64

# %%
t.decade.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
t.decade.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='decade'>

# %%
t.decade.value_counts()
# Out:
# decade
# 2010    65830
# 2000    35730
# 1990    21547
# 1980    19532
# 1970    18476
# 1960    17419
# 1950    12664
# 1930    10245
# 1920     8954
# 1940     8561
# 1910     6752
# 2020      260
# 1900       39
# 1890        3
# 2110        1
# Name: count, dtype: int64

# %%
t = titles
t = t.decade.value_counts()
t.sort_index()
# Out:
# decade
# 1890        3
# 1900       39
# 1910     6752
# 1920     8954
# 1930    10245
# 1940     8561
# 1950    12664
# 1960    17419
# 1970    18476
# 1980    19532
# 1990    21547
# 2000    35730
# 2010    65830
# 2020      260
# 2110        1
# Name: count, dtype: int64

# %%
t.sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='decade'>

# %%
t.sort_index().plot(kind="line")
# Out:
# <Axes: xlabel='decade'>

# %%
t.sort_index().plot(kind="line",title="Number of films by decade", xlim=(1890,2010), ylabel = "# of films")
# Out:
# <Axes: title={'center': 'Number of films by decade'}, xlabel='decade', ylabel='# of films'>

# %% [markdown]
# ### Plot the number of "Hamlet" films made each decade.

# %%
t = titles
t = t[t.title == "Hamlet"]
bbb.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Plot the number of "Rustler" characters in each decade of the history of film.

# %% [markdown]
# ### Plot the number of "Hamlet" characters each decade.

# %% [markdown]
# ### What are the 11 most common character names in movie history?

# %% [markdown]
# ### Who are the 10 people most often credited as "Herself" in film history?

# %% [markdown]
# ### Who are the 10 people most often credited as "Himself" in film history?

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1945?

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1985?

# %% [markdown]
# ### Plot how many roles Mammootty has played in each year of his career.

# %% [markdown]
# ### What are the 10 most frequent roles that start with the phrase "Patron in"?

# %% [markdown]
# ### What are the 10 most frequent roles that start with the word "Science"?

# %% [markdown]
# ### Plot the n-values of the roles that Judi Dench has played over her career.

# %% [markdown]
# ### Plot the n-values of Cary Grant's roles through his career.

# %% [markdown]
# ### Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %% [markdown]
# ### How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %% [markdown]
# # Excercise 3

# %%
t = titles

# %%
t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %%
t.set_index('year')
# Out:
#                                      title  decade
# year
# 1953                            El plebeyo    1950
# 1989          Atoski vrtovi - preobrazenje    1980
# 2006                        Mateegy norkos    2000
# 1936                         Lanka Dahanam    1930
# 1933                               Acciaio    1930
# ...                                    ...     ...
# 1919                         Eyes of Youth    1910
# 2002                                Madrid    2000
# 1924                   Ridgeway of Montana    1920
# 1961                     Professor Mamlock    1960
# 1984  Zui jia pai dang 3: Nu huang mi ling    1980
#
# [226013 rows x 2 columns]

# %%
t.reset_index(drop=True)
# Out:
#                                        title  year  decade
# 0                                 El plebeyo  1953    1950
# 1               Atoski vrtovi - preobrazenje  1989    1980
# 2                             Mateegy norkos  2006    2000
# 3                              Lanka Dahanam  1936    1930
# 4                                    Acciaio  1933    1930
# ...                                      ...   ...     ...
# 226008                         Eyes of Youth  1919    1910
# 226009                                Madrid  2002    2000
# 226010                   Ridgeway of Montana  1924    1920
# 226011                     Professor Mamlock  1961    1960
# 226012  Zui jia pai dang 3: Nu huang mi ling  1984    1980
#
# [226013 rows x 3 columns]

# %%
# %%timeit
t[t.title == "Hamlet"]
# Out:
# 22.9 ms ± 1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
nt = t.set_index('title')

# %%
# %%timeit
nt.loc["Hamlet"]
# Out:
# 8.26 ms ± 165 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
nt = nt.sort_index()

# %%
nt
# Out:
#                             year  decade
# title
# #211                        2018    2010
# #5                          2013    2010
# #50Fathers                  2015    2010
# #66                         2015    2010
# #73, Shaanthi Nivaasa       2007    2000
# ...                          ...     ...
# www.XXX.com                 2003    2000
# xXx                         2002    2000
# xXx: Return of Xander Cage  2017    2010
# xXx: State of the Union     2005    2000
# NaN                         2015    2010
#
# [226013 rows x 2 columns]

# %%
# %%timeit
nt.loc["Hamlet"]
# Out:
# 21.7 ms ± 2.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
t = titles

# %%
t.loc[2]
# Out:
# title     Mateegy norkos
# year                2006
# decade              2000
# Name: 2, dtype: object

# %%
t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %%
t.loc[3,'decade'] =2024

# %%
t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    2024
# 4                       Acciaio  1933    1930

# %%
t.iloc[3,2]
# Out:
# 1930

# %%
t.loc[t.title == "Hamlet", 'decade'] = 2024
t.loc[t.title == "Hamlet"]
# Out:
#          title  year  decade
# 5103    Hamlet  1910    2024
# 12003   Hamlet  1996    2024
# 13749   Hamlet  1987    2024
# 29426   Hamlet  2014    2024
# 37979   Hamlet  1976    2024
# 40775   Hamlet  2017    2024
# 50554   Hamlet  1921    2024
# 56379   Hamlet  1948    2024
# 66654   Hamlet  1990    2024
# 111648  Hamlet  1973    2024
# 115763  Hamlet  2000    2024
# 131005  Hamlet  1954    2024
# 132387  Hamlet  2011    2024
# 136491  Hamlet  2016    2024
# 138703  Hamlet  1969    2024
# 171280  Hamlet  1913    2024
# 189874  Hamlet  2015    2024
# 198468  Hamlet  1964    2024
# 198763  Hamlet  1911    2024
# 207508  Hamlet  2009    2024

# %%
t.iloc[2:3,1:2]
# Out:
#    year
# 2  2006

# %%
t.loc[:,'title':'year']
# Out:
#                                        title  year
# 0                                 El plebeyo  1953
# 1               Atoski vrtovi - preobrazenje  1989
# 2                             Mateegy norkos  2006
# 3                              Lanka Dahanam  1936
# 4                                    Acciaio  1933
# ...                                      ...   ...
# 226008                         Eyes of Youth  1919
# 226009                                Madrid  2002
# 226010                   Ridgeway of Montana  1924
# 226011                     Professor Mamlock  1961
# 226012  Zui jia pai dang 3: Nu huang mi ling  1984
#
# [226013 rows x 2 columns]

# %%
cast = pd.read_csv('cast.csv')
c = cast
c.head()
# Out:
#                   title    year      name   type                character  \
# 0        Closet Monster  2015.0  Buffy #1  actor                  Buffy 4
# 1       Suuri illusioni  1985.0    Homo $  actor                   Guests
# 2   Battle of the Sexes  2017.0   $hutter  actor          Bobby Riggs Fan
# 3  Secret in Their Eyes  2015.0   $hutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015.0   $hutter  actor  1988 Opera House Patron
#
#       n
# 0  31.0
# 1  22.0
# 2  10.0
# 3   NaN
# 4   NaN

# %%
c.loc[:, 'year':'type']
# Out:
#          year             name   type
# 0      2015.0         Buffy #1  actor
# 1      1985.0           Homo $  actor
# 2      2017.0          $hutter  actor
# 3      2015.0          $hutter  actor
# 4      2015.0          $hutter  actor
# ...       ...              ...    ...
# 36427  1961.0  Leonel Allegues  actor
# 36428  2014.0      Zakia Allel  actor
# 36429  2002.0        Eli Allem  actor
# 36430  2012.0    Layachi Allem  actor
# 36431     NaN              NaN    NaN
#
# [36432 rows x 3 columns]

# %%
c.loc[c.name == '$hutter','name'] = 'Shutter'
c.head()
# Out:
#                   title    year      name   type                character  \
# 0        Closet Monster  2015.0  Buffy #1  actor                  Buffy 4
# 1       Suuri illusioni  1985.0    Homo $  actor                   Guests
# 2   Battle of the Sexes  2017.0   Shutter  actor          Bobby Riggs Fan
# 3  Secret in Their Eyes  2015.0   Shutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015.0   Shutter  actor  1988 Opera House Patron
#
#       n
# 0  31.0
# 1  22.0
# 2  10.0
# 3   NaN
# 4   NaN

# %%
c[c.name =="Shutter",'name'] = "Hatter"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-1051be34cc15> in <cell line: 1>()
# ----> 1 c[c.name =="Shutter",'name'] = "Hatter"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4144
#    4145         if (
# -> 4146             key in self.columns
#    4147             and value.ndim == 1
#    4148             and not is_extension_array_dtype(value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    5142         False
#    5143         """
# -> 5144         hash(key)
# ...

# %%
c
# Out:
#                             title    year             name   type  \
# 0                  Closet Monster  2015.0         Buffy #1  actor
# 1                 Suuri illusioni  1985.0           Homo $  actor
# 2             Battle of the Sexes  2017.0          Shutter  actor
# 3            Secret in Their Eyes  2015.0          Shutter  actor
# 4                      Steve Jobs  2015.0          Shutter  actor
# ...                           ...     ...              ...    ...
# 36427            El joven rebelde  1961.0  Leonel Allegues  actor
# 36428                Freddy Hotel  2014.0      Zakia Allel  actor
# 36429  Muhammad: The Last Prophet  2002.0        Eli Allem  actor
# 36430                         Ouf  2012.0    Layachi Allem  actor
# 36431          Hot Tub Time Machi     NaN              NaN    NaN
#
#                            character     n
# 0                            Buffy 4  31.0
# 1                             Guests  22.0
# ...

# %% [markdown]
# # How many leading (n=1) roles were available to actors,
# # and how many to actresses, in each year of the 1950s?

# %%
cast = pd.read_csv('cast.csv')
len(cast)
# Out:
# 359758

# %%
c = cast
c  =c [c.year // 10 == 198 ]
c =  c[c.n == 1]
c
# Out:
#                              title  year               name   type  \
# 429                       Paradise  1982       Willie Aames  actor
# 1074                        Anemia  1987    Levan Abashidze  actor
# 1110        Attila flagello di Dio  1982  Diego Abatantuono  actor
# 1111        Attila flagello di Dio  1982  Diego Abatantuono  actor
# 1119    Eccezzziunale... veramente  1982  Diego Abatantuono  actor
# ...                            ...   ...                ...    ...
# 358135         The Meaning of Life  1983     Graham Chapman  actor
# 358136         The Meaning of Life  1983     Graham Chapman  actor
# 358137         The Meaning of Life  1983     Graham Chapman  actor
# 358141                 Yellowbeard  1983     Graham Chapman  actor
# 359280           The Fruit Machine  1988      Emile Charles  actor
#
#              character    n
# 429              David  1.0
# 1074              Nika  1.0
# 1110          Aldarico  1.0
# 1111            Attila  1.0
# ...

# %%
c.type.value_counts()
# Out:
# type
# actor    124
# Name: count, dtype: int64

# %%
c['title']
# Out:
# 1795                 Abbott and Costello Go to Mars
# 1796      Abbott and Costello in the Foreign Legion
# 1797          Abbott and Costello Meet Captain Kidd
# 1798     Abbott and Costello Meet the Keystone Kops
# 1803                      Comin' Round the Mountain
#                             ...
# 35487                                 Hicran yarasi
# 35497                                   Kalpaklilar
# 35500                        Kendini kurtaran sehir
# 35615                                     Ogni Baku
# 35806                      Isini chamovidnen mtidan
# Name: title, Length: 124, dtype: object

# %%
c[['title', 'type']]
# Out:
#                                             title   type
# 1795               Abbott and Costello Go to Mars  actor
# 1796    Abbott and Costello in the Foreign Legion  actor
# 1797        Abbott and Costello Meet Captain Kidd  actor
# 1798   Abbott and Costello Meet the Keystone Kops  actor
# 1803                    Comin' Round the Mountain  actor
# ...                                           ...    ...
# 35487                               Hicran yarasi  actor
# 35497                                 Kalpaklilar  actor
# 35500                      Kendini kurtaran sehir  actor
# 35615                                   Ogni Baku  actor
# 35806                    Isini chamovidnen mtidan  actor
#
# [124 rows x 2 columns]

# %%
na

# %%
c.groupby(['year','type']).size()
# Out:
# year  type
# 1980  actor    119
# 1981  actor    124
# 1982  actor    131
# 1983  actor    139
# 1984  actor     98
# 1985  actor    117
# 1986  actor    130
# 1987  actor    135
# 1988  actor    158
# 1989  actor    152
# dtype: int64
