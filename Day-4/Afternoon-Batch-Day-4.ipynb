# %%
import pandas as pd

# %%
# !pwd
# Out:
# /c/Users/as250199/class

# %%
path = r'C:\Users\as250199\Downloads\cast.csv'

# %%
cast = pd.read_csv(path)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[cast['title'] == "Inception"]
# Out:
#              title  year                  name     type  \
# 90228    Inception  2010  Michael (III) August    actor
# 136913   Inception  2010          Peter Basham    actor
# 168897   Inception  2010          Tom Berenger    actor
# 181725   Inception  2010              Ken Bhan    actor
# 238644   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3084390  Inception  2010            Ellen Page  actress
# 3136148  Inception  2010        Nicole Pulliam  actress
# 3161648  Inception  2010    Lisa (II) Reynolds  actress
# 3168008  Inception  2010         Talulah Riley  actress
# 3393649  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 90228            LAX Passenger   NaN
# 136913   Fischer's Jet Captain  44.0
# 168897                Browning   8.0
# 181725        Mombasan Gambler   NaN
# 238644          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
len(cast[cast['title'] == "Inception"])
# Out:
# 78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
pd.isnull("ashutosh")
# Out:
# False

# %%
import numpy as np
pd.isnull(np.NaN)
# Out:
# True

# %%
cast[cast['n'].isnull()]
# Out:
#                           title  year                         name     type  \
# 3          Secret in Their Eyes  2015                      $hutter    actor
# 4                    Steve Jobs  2015                      $hutter    actor
# 5        Straight Outta Compton  2015                      $hutter    actor
# 6        Straight Outta Compton  2015                      $hutter    actor
# 7                For Thy Love 2  2009                 Bee Moe $lim    actor
# ...                         ...   ...                          ...      ...
# 3442886               Svanurinn  2017      Katla M. Þorgeirsdóttir  actress
# 3442892               Foreldrar  2007  Lilja Guðrún Þorvaldsdóttir  actress
# 3442893                 Rokland  2011  Lilja Guðrún Þorvaldsdóttir  actress
# 3442894                      XL  2013  Lilja Guðrún Þorvaldsdóttir  actress
# 3442901       Bye Bye Blue Bird  1999                 Rosa á Rógvu  actress
#
#                           character   n
# ...

# %%
c = cast
c = c[c['title'] == 'Inception']
c = c[c['n'].isnull()]
len(c)
# Out:
# 27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
c = cast
c = c[c['title'] == 'Inception']
c = c[c['n'].notnull()]
len(c)
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
c = cast
c = c[c['title'] == 'North by Northwest']
c = c.sort_values('n')
c = c[c['n'].notnull()]
c
# Out:
#                       title  year                  name     type  \
# 797150   North by Northwest  1959            Cary Grant    actor
# 3201980  North by Northwest  1959       Eva Marie Saint  actress
# 1333732  North by Northwest  1959           James Mason    actor
# 2878461  North by Northwest  1959   Jessie Royce Landis  actress
# 326415   North by Northwest  1959        Leo G. Carroll    actor
# 2780220  North by Northwest  1959  Josephine Hutchinson  actress
# 1551491  North by Northwest  1959           Philip Ober    actor
# 1167105  North by Northwest  1959         Martin Landau    actor
# 2239203  North by Northwest  1959         Adam Williams    actor
# 1657968  North by Northwest  1959          Edward Platt    actor
# 609229   North by Northwest  1959     Robert Ellenstein    actor
# 2100440  North by Northwest  1959          Les Tremayne    actor
# 425645   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
c = cast
c = c[(c['title'] == 'Sleuth') & (c['year'] == 1972)]
c = c.sort_values('n')
c
# Out:
#           title  year                name     type  \
# 1560814  Sleuth  1972    Laurence Olivier    actor
# 299291   Sleuth  1972       Michael Caine    actor
# 342151   Sleuth  1972      Alec Cawthorne    actor
# 1341313  Sleuth  1972  John (II) Matthews    actor
# 2490141  Sleuth  1972  Eve (III) Channing  actress
# 1325945  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1560814                 Andrew Wyke  1.0
# 299291                  Milo Tindle  2.0
# 342151            Inspector Doppler  3.0
# 1341313  Detective Sergeant Tarrant  4.0
# 2490141             Marguerite Wyke  5.0
# 1325945      Police Constable Higgs  6.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
c = cast
c = c[(c['title'] == 'Sleuth') & (c['year'] == 1972)]
c = c.sort_values('n', ascending=False)

# %%
c
# Out:
#           title  year                name     type  \
# 1325945  Sleuth  1972        Teddy Martin    actor
# 2490141  Sleuth  1972  Eve (III) Channing  actress
# 1341313  Sleuth  1972  John (II) Matthews    actor
# 342151   Sleuth  1972      Alec Cawthorne    actor
# 299291   Sleuth  1972       Michael Caine    actor
# 1560814  Sleuth  1972    Laurence Olivier    actor
#
#                           character    n
# 1325945      Police Constable Higgs  6.0
# 2490141             Marguerite Wyke  5.0
# 1341313  Detective Sergeant Tarrant  4.0
# 342151            Inspector Doppler  3.0
# 299291                  Milo Tindle  2.0
# 1560814                 Andrew Wyke  1.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
c = cast
c = c[(c['title'] == 'Hamlet') & (c['year']==1996)]
c = c[c['n'].notnull()]

# %%
len(c)
# Out:
# 46

# %%
c = cast
c = c[(c.title == 'Hamlet') & (c.year==1996)]
c = c[c.n.notnull()]
c
# Out:
#           title  year                    name     type  \
# 1547     Hamlet  1996              Riz Abbasi    actor
# 88092    Hamlet  1996    Richard Attenborough    actor
# 145683   Hamlet  1996     Simon Russell Beale    actor
# 196937   Hamlet  1996         David (V) Blair    actor
# 201517   Hamlet  1996           Brian Blessed    actor
# 238732   Hamlet  1996         Kenneth Branagh    actor
# 250230   Hamlet  1996          Richard Briers    actor
# 270007   Hamlet  1996          Michael Bryant    actor
# 292609   Hamlet  1996            Peter Bygott    actor
# 458407   Hamlet  1996           Billy Crystal    actor
# 474456   Hamlet  1996           Charles Daish    actor
# 527361   Hamlet  1996        Gérard Depardieu    actor
# 548010   Hamlet  1996          Reece Dinsdale    actor
# 553205   Hamlet  1996                Ken Dodd    actor
# 601015   Hamlet  1996             Rob Edwards    actor
# 644433   Hamlet  1996        Nicholas Farrell    actor
# ...

# %%
c = cast
c
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3442897                           Foxtrot  1988            Lilja Þórisdóttir
# 3442898  Niceland (Population. 1.000.002)  2004    Sigríður Jóna Þórisdóttir
# 3442899                         Skammdegi  1985           Dalla Þórðardóttir
# 3442900                      U.S.S.S.S...  2003  Kristín Andrea Þórðardóttir
# 3442901                 Bye Bye Blue Bird  1999                 Rosa á Rógvu
#
# ...

# %%
c['Done By'] = 'Ashutosh'
c.head()
# Out:
#                   title  year      name   type                character     n  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN
#
#     Done By
# 0  Ashutosh
# 1  Ashutosh
# 2  Ashutosh
# 3  Ashutosh
# 4  Ashutosh

# %%
c.test = 'Hello'

# %%
c
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3442897                           Foxtrot  1988            Lilja Þórisdóttir
# 3442898  Niceland (Population. 1.000.002)  2004    Sigríður Jóna Þórisdóttir
# 3442899                         Skammdegi  1985           Dalla Þórðardóttir
# 3442900                      U.S.S.S.S...  2003  Kristín Andrea Þórðardóttir
# 3442901                 Bye Bye Blue Bird  1999                 Rosa á Rógvu
#
# ...

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
c = cast 
c = c[c.year // 10 == 198]
c = c[c.n.isnull()]

# %%
c
# Out:
#                        title  year               name     type  \
# 128                Plainsong  1982             Mick 5    actor
# 169      Me'Ahorei Hasoragim  1984  Yussuf Abed A'Nur    actor
# 175                  Hei dao  1989            Yunga A    actor
# 295                    Babul  1986             Aakash    actor
# 385                    Linna  1986    Kalevi Aaltonen    actor
# ...                      ...   ...                ...      ...
# 3442800     Kamilla og tyven  1988     Gwynn Øverland  actress
# 3442801  Kamilla og tyven II  1989     Gwynn Øverland  actress
# 3442814             Piratene  1983        Torill Øyen  actress
# 3442821    Seytanin ogullari  1987         Ülkü Ülker  actress
# 3442858       Candan sevmeli  1985      Aysegül Ünsal  actress
#
#                character   n   Done By
# 128           Fred Payne NaN  Ashutosh
# 169               Rashid NaN  Ashutosh
# 175              Li Xiao NaN  Ashutosh
# 295                Ashok NaN  Ashutosh
# ...

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
titles = pd.read_csv(r'C:\Users\as250199\Downloads\titles.csv')
titles.head()
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933

# %%
titles.title.value_counts()
# Out:
# title
# Hamlet                                     20
# Carmen                                     17
# Macbeth                                    16
# The Outsider                               12
# The Three Musketeers                       11
#                                            ..
# The Brave Frog's Greatest Adventure         1
# Fylakes anilikon No 2: Ekdikisi sti via     1
# Calling All Marines                         1
# Manhattan Heartbeat                         1
# Zui jia pai dang 3: Nu huang mi ling        1
# Name: count, Length: 207630, dtype: int64

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
t = titles 
t = t[t.year // 10 == 193].year.value_counts().head(3)

# %%
t
# Out:
# year
# 1937    1217
# 1938    1161
# 1936    1153
# Name: count, dtype: int64

# %% [markdown]
# ## Plot the number of films that have been released each decade over the history of cinema.

# %%
t = titles 
t['decade'] = t.year // 10 * 10 
t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %%
t.decade.value_counts()
# Out:
# decade
# 2010    65830
# 2000    35730
# 1990    21547
# 1980    19532
# 1970    18476
# 1960    17419
# 1950    12664
# 1930    10245
# 1920     8954
# 1940     8561
# 1910     6752
# 2020      260
# 1900       39
# 1890        3
# 2110        1
# Name: count, dtype: int64

# %%
t = t.decade.value_counts()
t.sort_index()
# Out:
# decade
# 1890        3
# 1900       39
# 1910     6752
# 1920     8954
# 1930    10245
# 1940     8561
# 1950    12664
# 1960    17419
# 1970    18476
# 1980    19532
# 1990    21547
# 2000    35730
# 2010    65830
# 2020      260
# 2110        1
# Name: count, dtype: int64

# %%
t.plot()
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
t
# Out:
# decade
# 2010    65830
# 2000    35730
# 1990    21547
# 1980    19532
# 1970    18476
# 1960    17419
# 1950    12664
# 1930    10245
# 1920     8954
# 1940     8561
# 1910     6752
# 2020      260
# 1900       39
# 1890        3
# 2110        1
# Name: count, dtype: int64

# %%
t.plot(kind = "hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
t.plot(kind = "bar")
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
t.sort_index().plot(kind = "bar")
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
t.sort_index().plot(kind = "line")
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
t.sort_index().plot(kind = "line", xlim =(1880, 2010))
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
t.sort_index().plot(kind = "line", xlim =(1880, 2010), ylabel = "# of movies")
# Out:
# <AxesSubplot: xlabel='decade', ylabel='# of movies'>

# %%
t.sort_index().plot(kind = "line", xlim =(1880, 2010), ylabel = "# of movies", title= "# of movies by Decade")
# Out:
# <AxesSubplot: title={'center': '# of movies by Decade'}, xlabel='decade', ylabel='# of movies'>

# %% [markdown]
# # Indexes

# %%
t = titles

# %%
t.head()
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    1930

# %%
t.set_index('year')
# Out:
#                                      title  decade
# year
# 1953                            El plebeyo    1950
# 1989          Atoski vrtovi - preobrazenje    1980
# 2006                        Mateegy norkos    2000
# 1936                         Lanka Dahanam    1930
# 1933                               Acciaio    1930
# ...                                    ...     ...
# 1919                         Eyes of Youth    1910
# 2002                                Madrid    2000
# 1924                   Ridgeway of Montana    1920
# 1961                     Professor Mamlock    1960
# 1984  Zui jia pai dang 3: Nu huang mi ling    1980
#
# [226013 rows x 2 columns]

# %%
t.reset_index(drop=True)
# Out:
#                                        title  year  decade
# 0                                 El plebeyo  1953    1950
# 1               Atoski vrtovi - preobrazenje  1989    1980
# 2                             Mateegy norkos  2006    2000
# 3                              Lanka Dahanam  1936    1930
# 4                                    Acciaio  1933    1930
# ...                                      ...   ...     ...
# 226008                         Eyes of Youth  1919    1910
# 226009                                Madrid  2002    2000
# 226010                   Ridgeway of Montana  1924    1920
# 226011                     Professor Mamlock  1961    1960
# 226012  Zui jia pai dang 3: Nu huang mi ling  1984    1980
#
# [226013 rows x 3 columns]

# %%
t
# Out:
#                                        title  year  decade
# 0                                 El plebeyo  1953    1950
# 1               Atoski vrtovi - preobrazenje  1989    1980
# 2                             Mateegy norkos  2006    2000
# 3                              Lanka Dahanam  1936    1930
# 4                                    Acciaio  1933    1930
# ...                                      ...   ...     ...
# 226008                         Eyes of Youth  1919    1910
# 226009                                Madrid  2002    2000
# 226010                   Ridgeway of Montana  1924    1920
# 226011                     Professor Mamlock  1961    1960
# 226012  Zui jia pai dang 3: Nu huang mi ling  1984    1980
#
# [226013 rows x 3 columns]

# %%
t.iloc[3,0]
# Out:
# 'Lanka Dahanam'

# %%
t.iloc[3,]
# Out:
# title     Lanka Dahanam
# year               1936
# decade             1930
# Name: 3, dtype: object

# %%
t.iloc[3,:]
# Out:
# title     Lanka Dahanam
# year               1936
# decade             1930
# Name: 3, dtype: object

# %%
t.iloc[4:8,0:2]
# Out:
#                     title  year
# 4                 Acciaio  1933
# 5          Lose Your Head  2013
# 6            Aane Pataaki  2013
# 7  Ad Augusta Per Angusta  2020

# %%
t.iloc[4:8,2] = 2024

# %%
t.head(10)
# Out:
#                           title  year  decade
# 0                    El plebeyo  1953    1950
# 1  Atoski vrtovi - preobrazenje  1989    1980
# 2                Mateegy norkos  2006    2000
# 3                 Lanka Dahanam  1936    1930
# 4                       Acciaio  1933    2024
# 5                Lose Your Head  2013    2024
# 6                  Aane Pataaki  2013    2024
# 7        Ad Augusta Per Angusta  2020    2024
# 8                  Oklahoma Jim  1931    1930
# 9       La culpa de los hombres  1955    1950

# %%
t
# Out:
#                                        title  year  decade
# 0                                 El plebeyo  1953    1950
# 1               Atoski vrtovi - preobrazenje  1989    1980
# 2                             Mateegy norkos  2006    2000
# 3                              Lanka Dahanam  1936    1930
# 4                                    Acciaio  1933    2024
# ...                                      ...   ...     ...
# 226008                         Eyes of Youth  1919    1910
# 226009                                Madrid  2002    2000
# 226010                   Ridgeway of Montana  1924    1920
# 226011                     Professor Mamlock  1961    1960
# 226012  Zui jia pai dang 3: Nu huang mi ling  1984    1980
#
# [226013 rows x 3 columns]

# %%
t.loc[3,]
# Out:
# title     Lanka Dahanam
# year               1936
# decade             1930
# Name: 3, dtype: object

# %%
t.loc[3,'year']
# Out:
# 1936

# %%
t.loc[4:8,'title':'year']
# Out:
#                     title  year
# 4                 Acciaio  1933
# 5          Lose Your Head  2013
# 6            Aane Pataaki  2013
# 7  Ad Augusta Per Angusta  2020
# 8            Oklahoma Jim  1931

# %%
t.loc[t.title == "Hamlet",]
# Out:
#          title  year  decade
# 5103    Hamlet  1910    1910
# 12003   Hamlet  1996    1990
# 13749   Hamlet  1987    1980
# 29426   Hamlet  2014    2010
# 37979   Hamlet  1976    1970
# 40775   Hamlet  2017    2010
# 50554   Hamlet  1921    1920
# 56379   Hamlet  1948    1940
# 66654   Hamlet  1990    1990
# 111648  Hamlet  1973    1970
# 115763  Hamlet  2000    2000
# 131005  Hamlet  1954    1950
# 132387  Hamlet  2011    2010
# 136491  Hamlet  2016    2010
# 138703  Hamlet  1969    1960
# 171280  Hamlet  1913    1910
# 189874  Hamlet  2015    2010
# 198468  Hamlet  1964    1960
# 198763  Hamlet  1911    1910
# 207508  Hamlet  2009    2000

# %%
cast
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3442897                           Foxtrot  1988            Lilja Þórisdóttir
# 3442898  Niceland (Population. 1.000.002)  2004    Sigríður Jóna Þórisdóttir
# 3442899                         Skammdegi  1985           Dalla Þórðardóttir
# 3442900                      U.S.S.S.S...  2003  Kristín Andrea Þórðardóttir
# 3442901                 Bye Bye Blue Bird  1999                 Rosa á Rógvu
#
# ...

# %% [markdown]
# # How many leading (n=1) roles were available to actors,
# # and how many to actresses, in each year of the 1950s?

# %%
c = cast

# %%
c = c[c.year // 10 == 195]
c = c[c.n == 1]
# c.type.value_counts()
c = c.groupby(['year','type']).size()

# %%
c
# Out:
# year  type
# 1950  actor      622
#       actress    287
# 1951  actor      640
#       actress    283
# 1952  actor      605
#       actress    300
# 1953  actor      648
#       actress    305
# 1954  actor      616
#       actress    311
# 1955  actor      634
#       actress    281
# 1956  actor      651
#       actress    304
# 1957  actor      700
#       actress    303
# 1958  actor      674
#       actress    292
# 1959  actor      692
#       actress    319
# dtype: int64

# %%
c.unstack()
# Out:
# type  actor  actress
# year
# 1950    622      287
# 1951    640      283
# 1952    605      300
# 1953    648      305
# 1954    616      311
# 1955    634      281
# 1956    651      304
# 1957    700      303
# 1958    674      292
# 1959    692      319

# %%
c.unstack('year')
# Out:
# year     1950  1951  1952  1953  1954  1955  1956  1957  1958  1959
# type
# actor     622   640   605   648   616   634   651   700   674   692
# actress   287   283   300   305   311   281   304   303   292   319

# %%
c
# Out:
# year  type
# 1950  actor      622
#       actress    287
# 1951  actor      640
#       actress    283
# 1952  actor      605
#       actress    300
# 1953  actor      648
#       actress    305
# 1954  actor      616
#       actress    311
# 1955  actor      634
#       actress    281
# 1956  actor      651
#       actress    304
# 1957  actor      700
#       actress    303
# 1958  actor      674
#       actress    292
# 1959  actor      692
#       actress    319
# dtype: int64

# %%
c
# Out:
# year  type
# 1950  actor      622
#       actress    287
# 1951  actor      640
#       actress    283
# 1952  actor      605
#       actress    300
# 1953  actor      648
#       actress    305
# 1954  actor      616
#       actress    311
# 1955  actor      634
#       actress    281
# 1956  actor      651
#       actress    304
# 1957  actor      700
#       actress    303
# 1958  actor      674
#       actress    292
# 1959  actor      692
#       actress    319
# dtype: int64

# %%
c.unstack(1)
# Out:
# type  actor  actress
# year
# 1950    622      287
# 1951    640      283
# 1952    605      300
# 1953    648      305
# 1954    616      311
# 1955    634      281
# 1956    651      304
# 1957    700      303
# 1958    674      292
# 1959    692      319

# %%
c = cast
c = c[c.year // 10 == 195]
c = c[c.n == 1]
# c.type.value_counts()
c = c.groupby(['type','year']).size()
c
# Out:
# type     year
# actor    1950    622
#          1951    640
#          1952    605
#          1953    648
#          1954    616
#          1955    634
#          1956    651
#          1957    700
#          1958    674
#          1959    692
# actress  1950    287
#          1951    283
#          1952    300
#          1953    305
#          1954    311
#          1955    281
#          1956    304
#          1957    303
#          1958    292
#          1959    319
# dtype: int64

# %%
c.unstack()
# Out:
# year     1950  1951  1952  1953  1954  1955  1956  1957  1958  1959
# type
# actor     622   640   605   648   616   634   651   700   674   692
# actress   287   283   300   305   311   281   304   303   292   319

# %%
c = c.unstack()

# %%
c
# Out:
# year     1950  1951  1952  1953  1954  1955  1956  1957  1958  1959
# type
# actor     622   640   605   648   616   634   651   700   674   692
# actress   287   283   300   305   311   281   304   303   292   319

# %%
c.stack()
# Out:
# type     year
# actor    1950    622
#          1951    640
#          1952    605
#          1953    648
#          1954    616
#          1955    634
#          1956    651
#          1957    700
#          1958    674
#          1959    692
# actress  1950    287
#          1951    283
#          1952    300
#          1953    305
#          1954    311
#          1955    281
#          1956    304
#          1957    303
#          1958    292
#          1959    319
# dtype: int64

# %%
c = c.stack()

# %%
c
# Out:
# type     year
# actor    1950    622
#          1951    640
#          1952    605
#          1953    648
#          1954    616
#          1955    634
#          1956    651
#          1957    700
#          1958    674
#          1959    692
# actress  1950    287
#          1951    283
#          1952    300
#          1953    305
#          1954    311
#          1955    281
#          1956    304
#          1957    303
#          1958    292
#          1959    319
# dtype: int64

# %%
c = c.unstack(0)

# %%
c['diff'] = c['actor'] - c['actress']
c
# Out:
# type  actor  actress  diff
# year
# 1950    622      287   335
# 1951    640      283   357
# 1952    605      300   305
# 1953    648      305   343
# 1954    616      311   305
# 1955    634      281   353
# 1956    651      304   347
# 1957    700      303   397
# 1958    674      292   382
# 1959    692      319   373

# %%
c = cast

# %%
c.head()
# Out:
#                   title  year      name   type                character     n  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN
#
#     Done By
# 0  Ashutosh
# 1  Ashutosh
# 2  Ashutosh
# 3  Ashutosh
# 4  Ashutosh

# %%
c.fillna(0).head()
# Out:
#                   title  year      name   type                character     n  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   0.0
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   0.0
#
#     Done By
# 0  Ashutosh
# 1  Ashutosh
# 2  Ashutosh
# 3  Ashutosh
# 4  Ashutosh

# %%
c.fillna(" ").head()
# Out:
#                   title  year      name   type                character     n  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron
#
#     Done By
# 0  Ashutosh
# 1  Ashutosh
# 2  Ashutosh
# 3  Ashutosh
# 4  Ashutosh

# %%
c.fillna(-1).head()
# Out:
#                   title  year      name   type                character     n  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan  -1.0
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron  -1.0
#
#     Done By
# 0  Ashutosh
# 1  Ashutosh
# 2  Ashutosh
# 3  Ashutosh
# 4  Ashutosh

# %%
c.n.fillna("HEllo")
# Out:
# 0           31.0
# 1           22.0
# 2           10.0
# 3          HEllo
# 4          HEllo
#            ...
# 3442897     24.0
# 3442898     26.0
# 3442899      9.0
# 3442900     17.0
# 3442901    HEllo
# Name: n, Length: 3442902, dtype: object
