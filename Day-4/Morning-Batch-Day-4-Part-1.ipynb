# %%
import pandas as pd

# %%
titles = pd.read_csv('titles.csv')
titles.head()
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933

# %%
titles.head(10)
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933
# 5                Lose Your Head  2013
# 6                  Aane Pataaki  2013
# 7        Ad Augusta Per Angusta  2020
# 8                  Oklahoma Jim  1931
# 9       La culpa de los hombres  1955

# %%
titles.head(1)
# Out:
#         title  year
# 0  El plebeyo  1953

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
type(titles)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titles)
# Out:
# 226013

# %%
titles.shape[0]
# Out:
# 226013

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.head()
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989
# 2                Mateegy norkos  2006
# 3                 Lanka Dahanam  1936
# 4                       Acciaio  1933

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 104859          Miss Jerry  1894
# 218352  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the single-word title "Hamlet"?

# %%
titles['title']
# Out:
# 0                                   El plebeyo
# 1                 Atoski vrtovi - preobrazenje
# 2                               Mateegy norkos
# 3                                Lanka Dahanam
# 4                                      Acciaio
#                           ...
# 226008                           Eyes of Youth
# 226009                                  Madrid
# 226010                     Ridgeway of Montana
# 226011                       Professor Mamlock
# 226012    Zui jia pai dang 3: Nu huang mi ling
# Name: title, Length: 226013, dtype: object

# %%
titles['title'] == "Hamlet"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 226008    False
# 226009    False
# 226010    False
# 226011    False
# 226012    False
# Name: title, Length: 226013, dtype: bool

# %%
titles[titles['title'] == "Hamlet"]
# Out:
#          title  year
# 5103    Hamlet  1910
# 12003   Hamlet  1996
# 13749   Hamlet  1987
# 29426   Hamlet  2014
# 37979   Hamlet  1976
# 40775   Hamlet  2017
# 50554   Hamlet  1921
# 56379   Hamlet  1948
# 66654   Hamlet  1990
# 111648  Hamlet  1973
# 115763  Hamlet  2000
# 131005  Hamlet  1954
# 132387  Hamlet  2011
# 136491  Hamlet  2016
# 138703  Hamlet  1969
# 171280  Hamlet  1913
# 189874  Hamlet  2015
# 198468  Hamlet  1964
# 198763  Hamlet  1911
# 207508  Hamlet  2009

# %%
type(titles['title'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
titles.head(2)
# Out:
#                           title  year
# 0                    El plebeyo  1953
# 1  Atoski vrtovi - preobrazenje  1989

# %%
len(titles[titles['title'] == "North by Northwest"])
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
t = titles.sort_values('year')
t.head()
# Out:
#                                                     title  year
# 104859                                         Miss Jerry  1894
# 218352                                 The Startled Lover  1898
# 26548      Reproduction of the Corbett and Jeffries Fight  1899
# 27917                                      May Day Parade  1900
# 206278  Pierrot's Problem, or How to Make a Fat Wife O...  1900

# %%
t[t.title == "Hamlet"].head(1)['year']
# Out:
# 5103    1910
# Name: year, dtype: int64

# %%
titles[titles['title'] == 'Hamlet'].sort_values('year').head(1)['year']
# Out:
# 5103    1910
# Name: year, dtype: int64

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles['title'] == "Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 37707   Treasure Island  1918
# 125462  Treasure Island  1920
# 177104  Treasure Island  1934
# 177713  Treasure Island  1950
# 166628  Treasure Island  1972
# 40833   Treasure Island  1973
# 181472  Treasure Island  1985
# 30150   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles['year'] == 1950]
# Out:
#                                title  year
# 16      Mrs. O'Malley and Mr. Malone  1950
# 266                     Lo zappatore  1950
# 277            Cuando el alba llegue  1950
# 281            The Invisible Monster  1950
# 794               Sekretnaya missiya  1950
# ...                              ...   ...
# 224640        Blue Grass of Kentucky  1950
# 225191                  State Secret  1950
# 225243             Wan jie qing yuan  1950
# 225265                      Gabriela  1950
# 225303                         Babul  1950
#
# [1109 rows x 2 columns]

# %% [markdown]
# ### How many movies were made in the year 1960?

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
t = titles

# %%
t[(t['year'] >= 1950) & (t['year'] <= 1959)]
# Out:
#                                title  year
# 0                         El plebeyo  1953
# 9            La culpa de los hombres  1955
# 16      Mrs. O'Malley and Mr. Malone  1950
# 26         The Sword of Monte Cristo  1951
# 32                 Women of Twilight  1952
# ...                              ...   ...
# 225839   Guardatele ma non toccatele  1959
# 225846               Suvarna Sundari  1957
# 225847            Norihei no daigaku  1956
# 225907        Frauenarzt Dr. Bertram  1957
# 225915  Die Trapp-Familie in Amerika  1958
#
# [12664 rows x 2 columns]

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
t[t['title'] == 'Batman']['year']
# Out:
# 164979    1989
# 191293    1943
# Name: year, dtype: int64

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
import pandas as pd

# %%
cast = pd.read_csv('cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
c = cast[cast['title'] == "Inception"]['n'].notnull().sum()
# c['n'].isnull().sum()
c
# Out:
# 20

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
c = cast[cast['title'] == 'North by Northwest']
c = c.sort_values('n')

# %%
c[c['n'].notnull()]
# Out:
#                      title  year               name   type  \
# 797150  North by Northwest  1959         Cary Grant  actor
# 326415  North by Northwest  1959     Leo G. Carroll  actor
# 609229  North by Northwest  1959  Robert Ellenstein  actor
# 425645  North by Northwest  1959    Philip Coolidge  actor
# 189719  North by Northwest  1959       Edward Binns  actor
#
#                  character     n
# 797150  Roger O. Thornhill   1.0
# 326415       The Professor   5.0
# 609229               Licht  11.0
# 425645           Dr. Cross  13.0
# 189719      Captain Junket  15.0

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast.head(2)
# Out:
#              title  year      name   type character     n
# 0   Closet Monster  2015  Buffy #1  actor   Buffy 4  31.0
# 1  Suuri illusioni  1985    Homo $  actor    Guests  22.0

# %%
cast[cast['character'] == 'Ophelia']
# Out:
#                                   title  year            name   type  \
# 227897       The Merry Maids of Madness  2016     Amy Bourque  actor
# 375914                   Jake Gets Paid  2009  Josie Chisholm  actor
# 792558  Dogg's Hamlet, Cahoot's Macbeth  2005   Lucas Grabeel  actor
#
#        character     n
# 227897   Ophelia  11.0
# 375914   Ophelia   NaN
# 792558   Ophelia   NaN

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %% [markdown]
# ### How many roles has Judi Dench played?

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
c = cast[(cast['year'] >= 1980) & (cast['year'] <= 1989)]
c['n'].isnull().sum()
# Out:
# 15382

# %%
c['n']
# Out:
# 1          22.0
# 66         46.0
# 115        28.0
# 128         NaN
# 169         NaN
#            ...
# 1078766    38.0
# 1078812    19.0
# 1078813    19.0
# 1079125    13.0
# 1079129     6.0
# Name: n, Length: 80693, dtype: float64

# %%
c.n
# Out:
# 1          22.0
# 66         46.0
# 115        28.0
# 128         NaN
# 169         NaN
#            ...
# 1078766    38.0
# 1078812    19.0
# 1078813    19.0
# 1079125    13.0
# 1079129     6.0
# Name: n, Length: 80693, dtype: float64

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c['My NEw Column'] = 12
# Out:
# <ipython-input-21-5590b0593856>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['My NEw Column'] = 12

# %%
c
# Out:
#                           title  year               name   type  \
# 1               Suuri illusioni  1985             Homo $  actor
# 66              Moord in extase  1984      Dick 't Hooft  actor
# 115      Hannah and Her Sisters  1986       The 39 Steps  actor
# 128                   Plainsong  1982             Mick 5  actor
# 169         Me'Ahorei Hasoragim  1984  Yussuf Abed A'Nur  actor
# ...                         ...   ...                ...    ...
# 1078766  The Malibu Bikini Shop  1986        Joel Kenney  actor
# 1078812            The Revenger  1989       Kenny (VIII)  actor
# 1078813            The Revenger  1989       Kenny (VIII)  actor
# 1079125       Soldier's Revenge  1986       George Kenny  actor
# 1079129    The Coolangatta Gold  1984        Grant Kenny  actor
#
#                      character     n  My NEw Column
# 1                       Guests  22.0             12
# 66       Officier van Justitie  46.0             12
# 115                  Rock Band  28.0             12
# 128                 Fred Payne   NaN             12
# 169                     Rashid   NaN             12
# ...                        ...   ...            ...
# 1078766        Delivery Man #1  38.0             12
# 1078812     Couple Making Love  19.0             12
# 1078813           Murder Scene  19.0             12
# 1079125                 Priest  13.0             12
# 1079129                  Grant   6.0             12
#
# [80693 rows x 7 columns]

# %%
c.My  new
# Out:
#   File "<ipython-input-23-2bac07ea352b>", line 1
#     c.My  new
#           ^
# SyntaxError: invalid syntax

# %%
c.extra = 14

# %%
c
# Out:
#                           title  year               name   type  \
# 1               Suuri illusioni  1985             Homo $  actor
# 66              Moord in extase  1984      Dick 't Hooft  actor
# 115      Hannah and Her Sisters  1986       The 39 Steps  actor
# 128                   Plainsong  1982             Mick 5  actor
# 169         Me'Ahorei Hasoragim  1984  Yussuf Abed A'Nur  actor
# ...                         ...   ...                ...    ...
# 1078766  The Malibu Bikini Shop  1986        Joel Kenney  actor
# 1078812            The Revenger  1989       Kenny (VIII)  actor
# 1078813            The Revenger  1989       Kenny (VIII)  actor
# 1079125       Soldier's Revenge  1986       George Kenny  actor
# 1079129    The Coolangatta Gold  1984        Grant Kenny  actor
#
#                      character     n  My NEw Column
# 1                       Guests  22.0             12
# 66       Officier van Justitie  46.0             12
# 115                  Rock Band  28.0             12
# 128                 Fred Payne   NaN             12
# 169                     Rashid   NaN             12
# ...                        ...   ...            ...
# 1078766        Delivery Man #1  38.0             12
# 1078812     Couple Making Love  19.0             12
# 1078813           Murder Scene  19.0             12
# 1079125                 Priest  13.0             12
# 1079129                  Grant   6.0             12
#
# [80693 rows x 7 columns]
